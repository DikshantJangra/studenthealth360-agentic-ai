# %% [markdown]
# # Milestone 1 — Data Cleaning & EDA
#
# This notebook was completed in Milestone 1. See the full version on Google Colab:
#
# **[Open in Colab](https://colab.research.google.com/drive/1mzHsZ85XsmSOWcDOzpGTqQdcqMXKR1yC)**
#
# ## Summary
# - Loaded raw student health dataset (1000 rows × 14 columns)
# - Cleaned data: removed Student_ID, handled missing values and outliers
# - Applied ordinal encoding (Physical_Activity, Sleep_Quality)
# - Applied one-hot encoding (Gender, Mood)
# - Applied standard scaling to numerical features
# - Output: cleaned_student_data.csv (1000 rows × 16 columns)
