# %% [markdown]
# # Milestone 1 — Data Modelling
#
# This notebook was completed in Milestone 1. See the full version on Google Colab:
#
# **[Open in Colab](https://colab.research.google.com/drive/1mzHsZ85XsmSOWcDOzpGTqQdcqMXKR1yC)**
#
# ## Summary
# - Trained logistic regression model on cleaned student health data
# - Multi-class classification: Low (0), Moderate (1), High (2) risk levels
# - 15 input features → Health_Risk_Level target
# - Model serialized as model.pkl
# - StandardScaler serialized as scaler.pkl
# - Evaluation metrics: accuracy, confusion matrix, classification report
